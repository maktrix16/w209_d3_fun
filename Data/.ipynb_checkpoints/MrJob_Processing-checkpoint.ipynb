# %%
# !head ../../Geolife_Trajectories_1.3/data_csv/000.csv
# Out:
# 000,39.984702,116.318417,492,2008-10-23,02:53:04,NA
# 000,39.984683,116.31845,492,2008-10-23,02:53:10,NA
# 000,39.984686,116.318417,492,2008-10-23,02:53:15,NA
# 000,39.984688,116.318385,492,2008-10-23,02:53:20,NA
# 000,39.984655,116.318263,492,2008-10-23,02:53:25,NA
# 000,39.984611,116.318026,493,2008-10-23,02:53:30,NA
# 000,39.984608,116.317761,493,2008-10-23,02:53:35,NA
# 000,39.984563,116.317517,496,2008-10-23,02:53:40,NA
# 000,39.984539,116.317294,500,2008-10-23,02:53:45,NA
# 000,39.984606,116.317065,505,2008-10-23,02:53:50,NA

# %%
# !rm ../../Geolife_Trajectories_1.3/toy_data
# !mkdir ../../Geolife_Trajectories_1.3/toy_data

# %%
# %%writefile ../../Geolife_Trajectories_1.3/toy_data/000.csv
# 000,39.984702,116.318417,492,2008-10-23,02:53:04,NA
# 000,39.984683,116.31845,492,2008-10-23,02:53:10,bike
# 000,39.984683,116.31845,492,2008-10-23,02:53:52,taxi
# Out:
# Writing ../../Geolife_Trajectories_1.3/toy_data/000.csv

# %%
# %%writefile ../../Geolife_Trajectories_1.3/toy_data/001.csv
# 001,39.984686,116.318417,492,2008-10-23,01:53:15,NA
# 001,39.984688,116.318385,492,2008-10-23,02:53:20,taxi
# 001,39.984606,116.317065,505,2008-10-23,02:53:50,taxi
# Out:
# Overwriting ../../Geolife_Trajectories_1.3/toy_data/001.csv

# %%
# %%writefile ../../Geolife_Trajectories_1.3/toy_data/002.csv
# 002,39.984655,116.318263,492,2008-10-23,02:51:25,taxi
# 002,39.984539,116.317294,500,2008-10-23,02:53:15,NA
# 002,39.984606,116.317065,505,2008-10-23,02:53:50,taxi
# Out:
# Writing ../../Geolife_Trajectories_1.3/toy_data/002.csv

# %%
# !aws s3 cp --recursive ../../Geolife_Trajectories_1.3/data_csv s3://w209-d3/data_csv
# Out:
# upload: ../../Geolife_Trajectories_1.3/data_csv/001.csv to s3://w209-d3/data_csv/001.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/000.csv to s3://w209-d3/data_csv/000.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/005.csv to s3://w209-d3/data_csv/005.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/006.csv to s3://w209-d3/data_csv/006.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/002.csv to s3://w209-d3/data_csv/002.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/004.csv to s3://w209-d3/data_csv/004.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/008.csv to s3://w209-d3/data_csv/008.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/009.csv to s3://w209-d3/data_csv/009.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/007.csv to s3://w209-d3/data_csv/007.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/003.csv to s3://w209-d3/data_csv/003.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/012.csv to s3://w209-d3/data_csv/012.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/011.csv to s3://w209-d3/data_csv/011.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/013.csv to s3://w209-d3/data_csv/013.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/015.csv to s3://w209-d3/data_csv/015.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/010.csv to s3://w209-d3/data_csv/010.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/014.csv to s3://w209-d3/data_csv/014.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/016.csv to s3://w209-d3/data_csv/016.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/019.csv to s3://w209-d3/data_csv/019.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/021.csv to s3://w209-d3/data_csv/021.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/020.csv to s3://w209-d3/data_csv/020.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/018.csv to s3://w209-d3/data_csv/018.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/023.csv to s3://w209-d3/data_csv/023.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/022.csv to s3://w209-d3/data_csv/022.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/024.csv to s3://w209-d3/data_csv/024.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/027.csv to s3://w209-d3/data_csv/027.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/017.csv to s3://w209-d3/data_csv/017.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/028.csv to s3://w209-d3/data_csv/028.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/029.csv to s3://w209-d3/data_csv/029.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/025.csv to s3://w209-d3/data_csv/025.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/031.csv to s3://w209-d3/data_csv/031.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/026.csv to s3://w209-d3/data_csv/026.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/033.csv to s3://w209-d3/data_csv/033.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/032.csv to s3://w209-d3/data_csv/032.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/034.csv to s3://w209-d3/data_csv/034.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/037.csv to s3://w209-d3/data_csv/037.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/030.csv to s3://w209-d3/data_csv/030.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/035.csv to s3://w209-d3/data_csv/035.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/036.csv to s3://w209-d3/data_csv/036.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/040.csv to s3://w209-d3/data_csv/040.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/038.csv to s3://w209-d3/data_csv/038.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/039.csv to s3://w209-d3/data_csv/039.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/043.csv to s3://w209-d3/data_csv/043.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/045.csv to s3://w209-d3/data_csv/045.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/047.csv to s3://w209-d3/data_csv/047.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/046.csv to s3://w209-d3/data_csv/046.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/048.csv to s3://w209-d3/data_csv/048.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/049.csv to s3://w209-d3/data_csv/049.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/044.csv to s3://w209-d3/data_csv/044.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/051.csv to s3://w209-d3/data_csv/051.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/042.csv to s3://w209-d3/data_csv/042.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/053.csv to s3://w209-d3/data_csv/053.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/041.csv to s3://w209-d3/data_csv/041.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/054.csv to s3://w209-d3/data_csv/054.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/056.csv to s3://w209-d3/data_csv/056.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/060.csv to s3://w209-d3/data_csv/060.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/058.csv to s3://w209-d3/data_csv/058.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/061.csv to s3://w209-d3/data_csv/061.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/050.csv to s3://w209-d3/data_csv/050.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/059.csv to s3://w209-d3/data_csv/059.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/055.csv to s3://w209-d3/data_csv/055.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/057.csv to s3://w209-d3/data_csv/057.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/063.csv to s3://w209-d3/data_csv/063.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/064.csv to s3://w209-d3/data_csv/064.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/052.csv to s3://w209-d3/data_csv/052.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/066.csv to s3://w209-d3/data_csv/066.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/062.csv to s3://w209-d3/data_csv/062.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/065.csv to s3://w209-d3/data_csv/065.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/069.csv to s3://w209-d3/data_csv/069.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/070.csv to s3://w209-d3/data_csv/070.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/072.csv to s3://w209-d3/data_csv/072.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/073.csv to s3://w209-d3/data_csv/073.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/076.csv to s3://w209-d3/data_csv/076.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/075.csv to s3://w209-d3/data_csv/075.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/077.csv to s3://w209-d3/data_csv/077.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/071.csv to s3://w209-d3/data_csv/071.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/080.csv to s3://w209-d3/data_csv/080.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/067.csv to s3://w209-d3/data_csv/067.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/079.csv to s3://w209-d3/data_csv/079.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/078.csv to s3://w209-d3/data_csv/078.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/081.csv to s3://w209-d3/data_csv/081.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/083.csv to s3://w209-d3/data_csv/083.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/074.csv to s3://w209-d3/data_csv/074.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/068.csv to s3://w209-d3/data_csv/068.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/082.csv to s3://w209-d3/data_csv/082.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/086.csv to s3://w209-d3/data_csv/086.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/087.csv to s3://w209-d3/data_csv/087.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/088.csv to s3://w209-d3/data_csv/088.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/089.csv to s3://w209-d3/data_csv/089.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/090.csv to s3://w209-d3/data_csv/090.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/091.csv to s3://w209-d3/data_csv/091.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/094.csv to s3://w209-d3/data_csv/094.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/093.csv to s3://w209-d3/data_csv/093.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/092.csv to s3://w209-d3/data_csv/092.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/095.csv to s3://w209-d3/data_csv/095.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/097.csv to s3://w209-d3/data_csv/097.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/098.csv to s3://w209-d3/data_csv/098.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/099.csv to s3://w209-d3/data_csv/099.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/100.csv to s3://w209-d3/data_csv/100.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/084.csv to s3://w209-d3/data_csv/084.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/101.csv to s3://w209-d3/data_csv/101.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/102.csv to s3://w209-d3/data_csv/102.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/105.csv to s3://w209-d3/data_csv/105.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/106.csv to s3://w209-d3/data_csv/106.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/107.csv to s3://w209-d3/data_csv/107.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/103.csv to s3://w209-d3/data_csv/103.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/108.csv to s3://w209-d3/data_csv/108.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/109.csv to s3://w209-d3/data_csv/109.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/110.csv to s3://w209-d3/data_csv/110.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/114.csv to s3://w209-d3/data_csv/114.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/111.csv to s3://w209-d3/data_csv/111.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/113.csv to s3://w209-d3/data_csv/113.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/116.csv to s3://w209-d3/data_csv/116.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/117.csv to s3://w209-d3/data_csv/117.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/118.csv to s3://w209-d3/data_csv/118.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/120.csv to s3://w209-d3/data_csv/120.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/104.csv to s3://w209-d3/data_csv/104.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/121.csv to s3://w209-d3/data_csv/121.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/123.csv to s3://w209-d3/data_csv/123.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/085.csv to s3://w209-d3/data_csv/085.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/096.csv to s3://w209-d3/data_csv/096.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/122.csv to s3://w209-d3/data_csv/122.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/115.csv to s3://w209-d3/data_csv/115.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/127.csv to s3://w209-d3/data_csv/127.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/125.csv to s3://w209-d3/data_csv/125.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/119.csv to s3://w209-d3/data_csv/119.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/112.csv to s3://w209-d3/data_csv/112.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/124.csv to s3://w209-d3/data_csv/124.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/129.csv to s3://w209-d3/data_csv/129.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/126.csv to s3://w209-d3/data_csv/126.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/132.csv to s3://w209-d3/data_csv/132.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/133.csv to s3://w209-d3/data_csv/133.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/130.csv to s3://w209-d3/data_csv/130.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/136.csv to s3://w209-d3/data_csv/136.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/138.csv to s3://w209-d3/data_csv/138.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/137.csv to s3://w209-d3/data_csv/137.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/139.csv to s3://w209-d3/data_csv/139.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/135.csv to s3://w209-d3/data_csv/135.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/134.csv to s3://w209-d3/data_csv/134.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/131.csv to s3://w209-d3/data_csv/131.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/128.csv to s3://w209-d3/data_csv/128.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/143.csv to s3://w209-d3/data_csv/143.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/140.csv to s3://w209-d3/data_csv/140.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/145.csv to s3://w209-d3/data_csv/145.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/142.csv to s3://w209-d3/data_csv/142.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/146.csv to s3://w209-d3/data_csv/146.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/149.csv to s3://w209-d3/data_csv/149.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/150.csv to s3://w209-d3/data_csv/150.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/151.csv to s3://w209-d3/data_csv/151.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/152.csv to s3://w209-d3/data_csv/152.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/148.csv to s3://w209-d3/data_csv/148.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/147.csv to s3://w209-d3/data_csv/147.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/141.csv to s3://w209-d3/data_csv/141.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/144.csv to s3://w209-d3/data_csv/144.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/154.csv to s3://w209-d3/data_csv/154.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/155.csv to s3://w209-d3/data_csv/155.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/156.csv to s3://w209-d3/data_csv/156.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/157.csv to s3://w209-d3/data_csv/157.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/158.csv to s3://w209-d3/data_csv/158.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/161.csv to s3://w209-d3/data_csv/161.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/162.csv to s3://w209-d3/data_csv/162.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/160.csv to s3://w209-d3/data_csv/160.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/159.csv to s3://w209-d3/data_csv/159.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/153.csv to s3://w209-d3/data_csv/153.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/164.csv to s3://w209-d3/data_csv/164.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/166.csv to s3://w209-d3/data_csv/166.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/165.csv to s3://w209-d3/data_csv/165.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/170.csv to s3://w209-d3/data_csv/170.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/173.csv to s3://w209-d3/data_csv/173.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/169.csv to s3://w209-d3/data_csv/169.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/171.csv to s3://w209-d3/data_csv/171.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/167.csv to s3://w209-d3/data_csv/167.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/174.csv to s3://w209-d3/data_csv/174.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/176.csv to s3://w209-d3/data_csv/176.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/178.csv to s3://w209-d3/data_csv/178.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/175.csv to s3://w209-d3/data_csv/175.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/172.csv to s3://w209-d3/data_csv/172.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/168.csv to s3://w209-d3/data_csv/168.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/163.csv to s3://w209-d3/data_csv/163.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/181.csv to s3://w209-d3/data_csv/181.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/177.csv to s3://w209-d3/data_csv/177.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/180.csv to s3://w209-d3/data_csv/180.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv/179.csv to s3://w209-d3/data_csv/179.csv

# %%
# !aws s3 cp --recursive ../../Geolife_Trajectories_1.3/data_csv_test s3://w209-d3/data_csv_test
# Out:
# upload: ../../Geolife_Trajectories_1.3/data_csv_test/000.csv to s3://w209-d3/data_csv_test/000.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv_test/001.csv to s3://w209-d3/data_csv_test/001.csv

# %%
# !head -n1000 ../../Geolife_Trajectories_1.3/data_csv/000.csv > ../../Geolife_Trajectories_1.3/data_csv_test_short/000.csv
# !head -n1000 ../../Geolife_Trajectories_1.3/data_csv/001.csv > ../../Geolife_Trajectories_1.3/data_csv_test_short/001.csv

# %%
# !aws s3 cp --recursive ../../Geolife_Trajectories_1.3/data_csv_test_short s3://w209-d3/data_csv_test_short
# Out:
# upload: ../../Geolife_Trajectories_1.3/data_csv_test_short/001.csv to s3://w209-d3/data_csv_test_short/001.csv
# upload: ../../Geolife_Trajectories_1.3/data_csv_test_short/000.csv to s3://w209-d3/data_csv_test_short/000.csv

# %%
from datetime import datetime

date,time=["2008-10-23", "02:53:04"]
dt = date+' '+time
a = datetime.strptime(dt, '%Y-%m-%d %H:%M:%S')
b = datetime(2008, 10, 23, 2, 53, 9)

time_diff=b-a

time_diff.total_seconds() < 6
# Out:
# True

# %% [markdown]
# #Calculate Distance

# %%
# %%writefile CalcDist.py

from mrjob.job import MRJob
from mrjob.step import MRStep
from datetime import datetime
import math
import ast

sort_conf = {
    'mapred.reduce.tasks': '1'
}

#convert coordinates to distance
def coor_to_km(x1,y1,x2,y2):
    R = 6371
    dx = (x2-x1) * math.pi / 180
    dy = (y2-y1) * math.pi / 180
    x1 *= math.pi / 180
    x2 *= math.pi / 180
    
    a = math.sin(dx/2)**2 + (math.sin(dy/2)**2) * (math.cos(x1)*math.cos(x2))
    c = 2*math.atan2(math.sqrt(a),math.sqrt(1-a))
    d = R * c
    return d

#convert to seconds (since python 2.6 or below does not have datetime.total_seconds()
#http://stackoverflow.com/questions/28089558/alternative-to-total-seconds-in-python-2-6
def timedelta_total_seconds(timedelta):
    return (
        timedelta.microseconds + 0.0 +
        (timedelta.seconds + timedelta.days * 24 * 3600) * 10 ** 6) / 10 ** 6


class CalcDist(MRJob):
    def steps(self):
        return [MRStep(mapper=self.mapper,
                       reducer_init=self.reducer_init,
                       reducer=self.reducer,
                       jobconf=sort_conf)]
    
    def mapper(self, _, line):
        user_id,x,y,alt,date,time,transport = line.strip().split(",")
        dt = date+' '+time
        yield (user_id,dt), (x,y,transport)
    

    def reducer_init(self):
        self.dt_initial = datetime(2008, 1, 1, 0, 0, 0)
        self.x_initial=0.0
        self.y_initial=0.0
        self.user = ''
        self.dist = {'all':0.0}

    
    def reducer(self, key, values):
        
        index=0
        user_id,dt = key
        dt_initial = datetime(2008, 1, 1, 0, 0, 0)
        dt_key = datetime.strptime(dt, '%Y-%m-%d %H:%M:%S')
        time_diff = dt_key - self.dt_initial
#         time_diff = time_diff.total_seconds()  #only for python 2.7 or above
        time_diff = timedelta_total_seconds(time_diff)
        self.dt_initial = dt_key
        
        for value in values:
            x_new,y_new,transport = value
            x_new=float(x_new)
            y_new=float(y_new)
            
            #assume only time interval with 5min belong to be in the same trip
            if time_diff < 300:
                distance = coor_to_km(self.x_initial,self.y_initial,x_new,y_new)
                self.dist['all'] += distance
                self.dist.setdefault(transport,0.0)
                self.dist[transport] += distance

            #if different user, reset distance counter
            if self.user != user_id:
                self.user = user_id
                self.dist = {'all':0.0}
                

            self.x_initial = x_new
            self.y_initial = y_new
            
            yield None, (user_id,dt,x_new,y_new,transport,self.dist)
            
if __name__ == '__main__':
    CalcDist.run()
# Out:
# Overwriting CalcDist.py

# %%
#create new job flow
# !python /Users/maktrix/Dropbox/Berkeley/W261_ML_scale/mrjob/mrjob/tools/emr/create_job_flow.py
# Out:
# using configs in /Users/maktrix/.mrjob.conf
# Creating persistent job flow to run several jobs in...
# creating tmp directory /var/folders/s3/ll81spln3fn418tf8hhv248m0000gn/T/no_script.maktrix.20151108.105200.610338
# writing master bootstrap script to /var/folders/s3/ll81spln3fn418tf8hhv248m0000gn/T/no_script.maktrix.20151108.105200.610338/b.py
# Copying non-input files into s3://w209-d3/no_script.maktrix.20151108.105200.610338/files/
# Waiting 5.0s for S3 eventual consistency
# Creating Elastic MapReduce job flow
# Job flow created with ID: j-1GNVZZQS3Z1VV
# j-1GNVZZQS3Z1VV

# %%
# %reload_ext autoreload
# %autoreload 2

import os

def mrjob_driver(inputfolder='', outputfolder='', onEMR=False, job_flow_id=''):
    
    from CalcDist import CalcDist

    if onEMR:
        os.system("aws s3 rm --recursive "+outputfolder)
        mr_job = CalcDist(args=[inputfolder,
                                '-r','emr',
                                '--emr-job-flow-id=' + job_flow_id,
                                '--output-dir=' + outputfolder])

    else: 
        # !rm -r ../../Geolife_Trajectories_1.3/local/calc-dist/
        mr_job = CalcDist(args=[inputfolder,
                                '--output-dir=' + '../../Geolife_Trajectories_1.3/local/calc-dist/'])

    with mr_job.make_runner() as runner:
        runner.run()

# run driver function (locally)
mrjob_driver(inputfolder='../../Geolife_Trajectories_1.3/toy_data')       

#run driver function (EMR)
# mrjob_driver(inputfolder='s3://w209-d3/data_csv/', 
#              outputfolder='s3://w209-d3/calc-dist2/data_csv/',
#              onEMR=True, 
#              job_flow_id='j-1GNVZZQS3Z1VV')

# %%
##EMR RESULTS
# import smart_open
# index = 0
# filename='s3://w209-d3/calc-dist/data_csv/part-00000'
# for line in smart_open.smart_open(filename):
#     print line.strip().split("\t")
#     index +=1
#     if index==10000: break

##LOCAL RESULTS  
# !cat ../../Geolife_Trajectories_1.3/local/calc-dist/*
# !head -n1000 ../../Geolife_Trajectories_1.3/local/calc-dist/*
# !tail -n50 ../../Geolife_Trajectories_1.3/local/calc-dist/*
# Out:
# null	["000", "2008-10-23 02:53:04", 39.984702, 116.318417, "NA", {"all": 0.0}]
# null	["000", "2008-10-23 02:53:10", 39.984683, 116.31845, "bike", {"all": 0.003516886428136976, "bike": 0.003516886428136976}]
# null	["000", "2008-10-23 02:53:52", 39.984683, 116.31845, "taxi", {"taxi": 0.0, "all": 0.003516886428136976, "bike": 0.003516886428136976}]
# null	["001", "2008-10-23 01:53:15", 39.984686, 116.318417, "NA", {"all": 0.0}]
# null	["001", "2008-10-23 02:53:20", 39.984688, 116.318385, "taxi", {"taxi": 0.002735434458433334, "all": 0.002735434458433334}]
# null	["001", "2008-10-23 02:53:50", 39.984606, 116.317065, "taxi", {"taxi": 0.11556766508739959, "all": 0.11556766508739959}]
# null	["002", "2008-10-23 02:51:25", 39.984655, 116.318263, "taxi", {"all": 0.0}]
# null	["002", "2008-10-23 02:53:15", 39.984539, 116.317294, "NA", {"NA": 0.08355982534929753, "all": 0.08355982534929753}]
# null	["002", "2008-10-23 02:53:50", 39.984606, 116.317065, "taxi", {"taxi": 0.020884688774914933, "NA": 0.08355982534929753, "all": 0.10444451412421246}]

# %% [markdown]
# #Main Aggregation MrJob

# %%
# %%writefile Aggregate.py

from mrjob.job import MRJob
from mrjob.step import MRStep
from mrjob.compat import jobconf_from_env
from datetime import datetime
from datetime import timedelta
import ast
import math
# from mrjob.protocol import JSONValueProtocol

sort_conf = {
    'mapred.reduce.tasks': '1'
}

class Aggregate(MRJob):

#     INPUT_PROTOCOL = JSONValueProtocol
    
    def steps(self):
        return [MRStep(mapper_init=self.mapper1_init,
                       mapper=self.mapper1,
                       reducer_init=self.reducer1_init,
                       reducer=self.reducer1,
                       reducer_final=self.reducer1_final
                      )
                ,
                MRStep(mapper=self.mapper2
                       ,
                       reducer_init=self.reducer2_init,
                       reducer=self.reducer2,
                       reducer_final=self.reducer2_final),
                MRStep(mapper=self.mapper3,
                       reducer=self.reducer3,
                       jobconf=sort_conf
                      )
               ]
    
    ### First MrJob: aggregate by the time interval
    
    
    def mapper1_init(self):
        self.interval = int(jobconf_from_env('interval'))
    
    def mapper1(self, _, line):
        key,data = line.strip().split("\t")
        
        user_id,dt,x_new,y_new,transport,dist = ast.literal_eval(data)
        dt_convert = datetime.strptime(dt, '%Y-%m-%d %H:%M:%S')
        sec = dt_convert.second
        remainder = sec%self.interval
        if remainder != 0:  
            update_sec = self.interval-remainder
        else:
            update_sec=0
        
        dt_convert += timedelta(0,update_sec)
        dt_convert = dt_convert.strftime("%Y-%m-%d %H:%M:%S")
        yield (dt_convert,user_id), (dt,x_new,y_new,transport,dist)
    
    def reducer1_init(self):
        self.current_dt = ''
        self.current_user=''
        self.current_max_dist = 0.0
        self.aggregate = {}

    
    def reducer1(self, key, values):
        dt_convert,user_id = key
        self.aggregate.setdefault(dt_convert,{})
        
        if dt_convert != self.current_dt or user_id != self.current_user:
            self.current_dt = dt_convert
            self.current_user = user_id
            self.current_max_dist = 0.0

        for value in values:
            dt,x_new,y_new,transport,dist = value
            if dist['all'] >= self.current_max_dist :
                self.current_max_dist = dist['all']
#                 value.append(user_id)
                self.aggregate[dt_convert][user_id]=value
        
    def reducer1_final(self):
        for dt_convert, values in self.aggregate.iteritems():
            for user_id, value in values.iteritems(): 
                dt,x_new,y_new,transport,dist = value
                yield dt_convert, (user_id,dt,x_new,y_new,transport,dist)
        
    ### 2nd MrJob: aggregate by the users within the time interval
   
    def mapper2(self, dt_convert, value):
        yield dt_convert, value
        
    def reducer2_init(self):
        self.current_dt = ''
        self.aggregate = {}
#         self.users={}
#         self.transports={}
        self.dists={}
            
    def reducer2(self, dt_convert, values): 
        
        for value in values:
            user_id,dt,x_new,y_new,transport,dists = value
            self.aggregate.setdefault(dt_convert,{})

            self.aggregate[dt_convert].setdefault("users",[])
            self.aggregate[dt_convert]["users"].append({user_id:[x_new,y_new,transport]})

            self.aggregate[dt_convert].setdefault("transports",{})
            self.aggregate[dt_convert]["transports"].setdefault(transport,0)
            self.aggregate[dt_convert]["transports"][transport]+=1

            for transport_mode,dist in dists.iteritems():
                self.dists.setdefault(transport_mode,0.0)
                self.dists[transport_mode] += dist
            
        self.aggregate[dt_convert]['dists'] = self.dists.copy()
                
    def reducer2_final(self):                         
        for dt_convert, value in self.aggregate.iteritems():
            yield dt_convert, value            

### 3rd MrJob: sort by dt_convert
    
    def mapper3(self,dt_convert,value):
        yield dt_convert,value
        
    def reducer3(self,dt_convert,values):
        for value in values:
            yield dt_convert,value
            
if __name__ == '__main__':
    Aggregate.run()
# Out:
# Overwriting Aggregate.py

# %%
#create new job flow (small cluster)
# !python /Users/maktrix/Dropbox/Berkeley/W261_ML_scale/mrjob/mrjob/tools/emr/create_job_flow.py
# Out:
# using configs in /Users/maktrix/.mrjob.conf
# Creating persistent job flow to run several jobs in...
# creating tmp directory /var/folders/s3/ll81spln3fn418tf8hhv248m0000gn/T/no_script.maktrix.20151107.134656.227702
# writing master bootstrap script to /var/folders/s3/ll81spln3fn418tf8hhv248m0000gn/T/no_script.maktrix.20151107.134656.227702/b.py
# Copying non-input files into s3://w209-d3/no_script.maktrix.20151107.134656.227702/files/
# Waiting 5.0s for S3 eventual consistency
# Creating Elastic MapReduce job flow
# Job flow created with ID: j-1JE76Q6E0IZLL
# j-1JE76Q6E0IZLL

# %%
# %reload_ext autoreload
# %autoreload 2

import os

def aggregate_driver(inputfolder='', outputfolder='', onEMR=False, job_flow_id=''):

    from Aggregate import Aggregate
    
    if onEMR:
        os.system("aws s3 rm "+inputfolder+"_SUCCESS")
        os.system("aws s3 rm --recursive "+outputfolder)
        mr_job = Aggregate(args=[inputfolder,
                                 '-r','emr',
                                 '--output-dir=' + outputfolder,
#                                  '--emr-job-flow-id=' + job_flow_id,
                                 '--jobconf', 'interval=15'])    
    else:
        # !rm -r ../../Geolife_Trajectories_1.3/local/aggregate/
        mr_job = Aggregate(args=[inputfolder,
                                 '--output-dir=' + '../../Geolife_Trajectories_1.3/local/aggregate3/',
                                 '--jobconf', 'interval=15'])
        
    with mr_job.make_runner() as runner:
        runner.run()

    
# run driver function (EMR)
aggregate_driver(inputfolder='s3://w209-d3/calc-dist/data_csv/', 
             outputfolder='s3://w209-d3/aggregate3/data_csv/',
             onEMR=True, 
             job_flow_id='j-1JE76Q6E0IZLL')
        
## run driver function (locally)
# aggregate_driver(inputfolder='../../Geolife_Trajectories_1.3/local/calc-dist/')

# %%
##EMR RESULTS
# import smart_open
# index = 0
# filename='s3://w209-d3/aggregate/data_csv/part-00000'
# for line in smart_open.smart_open(filename):
#     print line.strip().split("\t")
#     index +=1
#     if index==10000: break

##LOCAL RESULTS
# !head -n100000 ../../Geolife_Trajectories_1.3/local/aggregate/*
# !cat ../../Geolife_Trajectories_1.3/local/aggregate/*
# Out:
# "2008-10-23 01:53:15"	{"transports": {"NA": 1}, "users": [{"001": [39.984686, 116.318417, "NA"]}], "dists": {"all": 0.0}}
# "2008-10-23 02:51:30"	{"transports": {"taxi": 1}, "users": [{"002": [39.984655, 116.318263, "taxi"]}], "dists": {"all": 0.0}}
# "2008-10-23 02:53:15"	{"transports": {"NA": 1, "bike": 1}, "users": [{"000": [39.984683, 116.31845, "bike"]}, {"002": [39.984539, 116.317294, "NA"]}], "dists": {"NA": 0.08355982534929753, "all": 0.0870767117774345, "bike": 0.003516886428136976}}
# "2008-10-23 02:53:30"	{"transports": {"taxi": 1}, "users": [{"001": [39.984688, 116.318385, "taxi"]}], "dists": {"taxi": 0.002735434458433334, "NA": 0.08355982534929753, "all": 0.08981214623586783, "bike": 0.003516886428136976}}
# "2008-10-23 02:54:00"	{"transports": {"taxi": 3}, "users": [{"000": [39.984683, 116.31845, "taxi"]}, {"001": [39.984606, 116.317065, "taxi"]}, {"002": [39.984606, 116.317065, "taxi"]}], "dists": {"taxi": 0.13918778832074785, "NA": 0.16711965069859505, "all": 0.31334121187561687, "bike": 0.007033772856273952}}

# %%
##EMR RESULTS
# import smart_open
# index = 0
# filename='s3://w209-d3/calc-dist/data_csv/part-00000'
# for line in smart_open.smart_open(filename):
#     print line.strip().split("\t")
#     index +=1
#     if index==10000: break

##LOCAL RESULTS
# !head -n100 ../../Geolife_Trajectories_1.3/local/aggregate/*
# !wc -l ../../Geolife_Trajectories_1.3/local/aggregate2/part-00000
# 2498351 ../../Geolife_Trajectories_1.3/local/aggregate2/part-00000


# !head -n1000000 ../../Geolife_Trajectories_1.3/local/aggregate2/* | tail -n5000
# !head -n1000000 ../../Geolife_Trajectories_1.3/local/aggregate3/* | tail -n5000
# Out:
# "2009-02-06 14:09:45"	{"transports": {"NA": 2}, "users": [{"038": [40.049968300000003, 116.3011116, "NA"]}, {"025": [31.904393299999999, 119.74674659999999, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623457657.5750589, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670877781.7660513, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:10:00"	{"transports": {"NA": 2}, "users": [{"038": [40.051600000000001, 116.30016329999999, "NA"]}, {"025": [31.907061599999999, 119.74254000000001, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628398999.3828278, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677619504.0825176, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:10:15"	{"transports": {"NA": 3}, "users": [{"140": [40.162759899999998, 116.19705329999999, "NA"]}, {"038": [40.053873299999999, 116.2988616, "NA"]}, {"025": [31.9097033, 119.7382733, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628407841.5100269, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677628346.2097168, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:10:30"	{"transports": {"NA": 3}, "users": [{"025": [31.912404899999999, 119.73384830000001, "NA"]}, {"038": [40.056240000000003, 116.29770000000001, "NA"]}, {"140": [40.166806600000001, 116.2013133, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628416685.011693, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677637189.7113829, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:10:45"	{"transports": {"NA": 3}, "users": [{"025": [31.915188300000001, 119.7292466, "NA"]}, {"140": [40.169874900000003, 116.20365, "NA"]}, {"038": [40.058513300000001, 116.29652830000001, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628425529.7134838, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677646034.4131737, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:11:00"	{"transports": {"NA": 2}, "users": [{"025": [31.918079899999999, 119.7245549, "NA"]}, {"038": [40.060656600000002, 116.2952466, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628618661.9961033, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677379243.1352367, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:11:15"	{"transports": {"NA": 2}, "users": [{"025": [31.920761599999999, 119.7195116, "NA"]}, {"038": [40.062191599999998, 116.2938499, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628623615.187973, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677384196.3271065, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:11:30"	{"transports": {"NA": 2}, "users": [{"025": [31.923400000000001, 119.71432160000001, "NA"]}, {"038": [40.063671599999999, 116.2932416, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628628569.1245489, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677389150.2636824, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:11:45"	{"transports": {"NA": 1}, "users": [{"025": [31.926034999999999, 119.7091216, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628633493.1770496, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677394074.3161831, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:12:00"	{"transports": {"NA": 1}, "users": [{"025": [31.9286633, 119.70393319999999, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623462582.1977949, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670882706.3887873, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:12:15"	{"transports": {"NA": 1}, "users": [{"025": [31.931328300000001, 119.69869989999999, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623467507.3964977, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670887631.5874901, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:12:30"	{"transports": {"NA": 1}, "users": [{"025": [31.9339716, 119.6934916, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623472433.1678772, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670892557.3588696, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:12:45"	{"transports": {"NA": 1}, "users": [{"025": [31.936628299999999, 119.6882899, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623477359.5121565, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670897483.7031488, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:13:00"	{"transports": {"NA": 1}, "users": [{"025": [31.9393083, 119.6830916, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628430456.6317263, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677650961.3314161, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:13:15"	{"transports": {"NA": 1}, "users": [{"025": [31.9421216, 119.6775233, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628435384.1614809, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677655888.8611708, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:13:30"	{"transports": {"NA": 1}, "users": [{"025": [31.9447899, 119.67234999999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628440312.2624722, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677660816.962162, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:13:45"	{"transports": {"NA": 1}, "users": [{"025": [31.947428299999999, 119.6671116, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628445240.9382448, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677665745.6379347, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:14:00"	{"transports": {"NA": 1}, "users": [{"025": [31.950074900000001, 119.661925, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628638422.4238672, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677399003.5630007, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:14:15"	{"transports": {"NA": 1}, "users": [{"025": [31.952753300000001, 119.65674660000001, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628643352.2428885, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677403933.3820219, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:14:30"	{"transports": {"NA": 1}, "users": [{"025": [31.9554166, 119.6515083, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628648282.6380739, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677408863.7772074, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:14:45"	{"transports": {"NA": 1}, "users": [{"025": [31.958068300000001, 119.64628500000001, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628653213.6075201, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677413794.7466536, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:15:00"	{"transports": {"NA": 1}, "users": [{"025": [31.960705000000001, 119.64103160000001, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623482291.0574741, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670902415.2484665, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:15:15"	{"transports": {"NA": 1}, "users": [{"025": [31.963284900000001, 119.6357799, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623487223.1752892, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670907347.3662815, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:15:30"	{"transports": {"NA": 1}, "users": [{"025": [31.965945000000001, 119.6305766, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623492155.8661909, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670912280.0571833, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:15:45"	{"transports": {"NA": 1}, "users": [{"025": [31.968609900000001, 119.6253916, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623497089.1289682, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670917213.3199606, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:16:00"	{"transports": {"NA": 1}, "users": [{"025": [31.971281600000001, 119.6201549, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628450174.7774515, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677670679.4771414, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:16:15"	{"transports": {"NA": 1}, "users": [{"025": [31.9739133, 119.61488490000001, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628455109.1934986, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677675613.8931885, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:16:30"	{"transports": {"NA": 1}, "users": [{"025": [31.976596600000001, 119.6097283, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628460044.1801739, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677680548.8798637, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:16:45"	{"transports": {"NA": 1}, "users": [{"025": [31.979241600000002, 119.60455829999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628464979.7363205, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677685484.4360104, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:17:00"	{"transports": {"NA": 1}, "users": [{"025": [31.981916600000002, 119.59934, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628658149.7387676, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677418730.8779011, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:17:15"	{"transports": {"NA": 1}, "users": [{"025": [31.985204899999999, 119.5946466, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628663086.4454803, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677423667.5846138, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:17:30"	{"transports": {"NA": 1}, "users": [{"025": [31.989415000000001, 119.59116659999999, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628668023.7255945, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677428604.864728, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:17:45"	{"transports": {"NA": 1}, "users": [{"025": [31.994238299999999, 119.5890849, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628672961.5781288, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677433542.7172623, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:18:00"	{"transports": {"NA": 1}, "users": [{"025": [31.999331600000001, 119.58813000000001, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623502027.5550699, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670922151.7460623, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:18:15"	{"transports": {"NA": 1}, "users": [{"025": [32.0044149, 119.5871916, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623506966.5532942, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670927090.7442865, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:18:30"	{"transports": {"NA": 1}, "users": [{"025": [32.009493300000003, 119.5862283, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623511906.1234713, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670932030.3144636, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:18:45"	{"transports": {"NA": 1}, "users": [{"025": [32.014549899999999, 119.5853649, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623516846.2617874, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670936970.4527798, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:19:00"	{"transports": {"NA": 2}, "users": [{"038": [40.069693299999997, 116.33058490000001, "NA"]}, {"025": [32.019571599999999, 119.5844566, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628469950.9004393, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677690455.6001291, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:19:15"	{"transports": {"NA": 2}, "users": [{"038": [40.069744900000003, 116.3307966, "NA"]}, {"025": [32.024501600000001, 119.58350160000001, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628474922.6403856, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677695427.3400755, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:19:30"	{"transports": {"NA": 2}, "users": [{"038": [40.069850000000002, 116.3307983, "NA"]}, {"025": [32.029339899999997, 119.58261330000001, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628479894.9401999, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677700399.6398897, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:19:45"	{"transports": {"NA": 1}, "users": [{"025": [32.034151600000001, 119.5817316, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628484837.2849073, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677705341.9845972, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:20:00"	{"transports": {"NA": 1}, "users": [{"025": [32.039014999999999, 119.58085320000001, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628677904.4699278, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677438485.6090612, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:20:15"	{"transports": {"NA": 1}, "users": [{"025": [32.044054899999999, 119.5799349, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628682847.928793, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677443429.0679264, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:20:30"	{"transports": {"NA": 1}, "users": [{"025": [32.049148299999999, 119.5797182, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628687791.9554958, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677448373.0946293, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:20:45"	{"transports": {"NA": 1}, "users": [{"025": [32.054121600000002, 119.5800716, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628692736.5363913, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677453317.6755247, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:21:00"	{"transports": {"NA": 1}, "users": [{"025": [32.058956600000002, 119.5795483, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623521791.3832703, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670941915.5742626, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:21:15"	{"transports": {"NA": 1}, "users": [{"025": [32.063528300000002, 119.57794, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623526737.0358458, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670946861.2268381, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:21:30"	{"transports": {"NA": 1}, "users": [{"025": [32.067676599999999, 119.5754582, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623531683.2060213, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670951807.3970137, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:21:45"	{"transports": {"NA": 1}, "users": [{"025": [32.071284900000002, 119.5721499, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623536629.8848829, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670956754.0758753, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:22:00"	{"transports": {"NA": 1}, "users": [{"025": [32.074458300000003, 119.5681266, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628489784.4821901, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677710289.18188, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:22:15"	{"transports": {"NA": 1}, "users": [{"025": [32.077461599999999, 119.5637983, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628494732.2065916, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677715236.9062815, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:22:30"	{"transports": {"NA": 1}, "users": [{"025": [32.080578299999999, 119.55920159999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628499680.4857082, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677720185.1853981, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:22:45"	{"transports": {"NA": 1}, "users": [{"025": [32.083784899999998, 119.55461, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628504629.3254328, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677725134.0251226, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:23:00"	{"transports": {"NA": 1}, "users": [{"025": [32.087049899999997, 119.54997, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628697685.944356, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677458267.0834894, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:23:15"	{"transports": {"NA": 1}, "users": [{"025": [32.0903633, 119.54544319999999, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628702635.9158897, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677463217.0550232, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:23:30"	{"transports": {"NA": 1}, "users": [{"025": [32.0937299, 119.54087319999999, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628707586.4579334, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677468167.5970669, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:23:45"	{"transports": {"NA": 1}, "users": [{"025": [32.097090000000001, 119.5363116, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628712537.5694036, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677473118.7085371, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:24:00"	{"transports": {"NA": 1}, "users": [{"025": [32.100599899999999, 119.531865, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623541581.5690737, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670961705.760066, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:24:15"	{"transports": {"NA": 1}, "users": [{"025": [32.104615000000003, 119.5280733, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623546533.8252535, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670966658.0162458, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:24:30"	{"transports": {"NA": 1}, "users": [{"025": [32.108703300000002, 119.52439990000001, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623551486.6527386, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670971610.8437309, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:24:45"	{"transports": {"NA": 1}, "users": [{"025": [32.112749999999998, 119.5207499, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623556440.0464964, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670976564.2374887, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:25:00"	{"transports": {"NA": 1}, "users": [{"025": [32.116789900000001, 119.5170816, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628509583.2859001, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677730087.98559, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:25:15"	{"transports": {"NA": 1}, "users": [{"025": [32.120783299999999, 119.51345329999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628514537.8066969, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677735042.5063868, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:25:30"	{"transports": {"NA": 1}, "users": [{"025": [32.124781599999999, 119.5097866, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628519492.8904285, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677739997.5901184, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:25:45"	{"transports": {"NA": 1}, "users": [{"025": [32.1288099, 119.5060866, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628524448.5416584, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677744953.2413483, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:26:00"	{"transports": {"NA": 1}, "users": [{"025": [32.132843299999998, 119.5024883, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628717493.7827406, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677478074.921874, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:26:15"	{"transports": {"NA": 1}, "users": [{"025": [32.137131599999996, 119.4994633, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628722450.5523739, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677483031.6915073, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:26:30"	{"transports": {"NA": 1}, "users": [{"025": [32.141883300000003, 119.49732659999999, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628727407.8876934, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677487989.0268269, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:26:45"	{"transports": {"NA": 1}, "users": [{"025": [32.146679900000002, 119.4952866, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628732365.7900133, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677492946.9291468, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:27:00"	{"transports": {"NA": 2}, "users": [{"038": [40.069841599999997, 116.3303866, "NA"]}, {"025": [32.151106599999999, 119.4923533, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623561429.0164833, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670981553.2074757, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:27:15"	{"transports": {"NA": 2}, "users": [{"038": [40.069826599999999, 116.33015330000001, "NA"]}, {"025": [32.155281600000002, 119.48909329999999, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623566418.5629673, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670986542.7539597, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:27:30"	{"transports": {"NA": 2}, "users": [{"025": [32.159458299999997, 119.4858266, "NA"]}, {"038": [40.069828299999998, 116.3300316, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623571408.6790047, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670991532.869997, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:27:45"	{"transports": {"NA": 2}, "users": [{"038": [40.069831600000001, 116.3300083, "NA"]}, {"025": [32.163566600000003, 119.4826216, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623576399.3454618, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5670996523.5364542, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:28:00"	{"transports": {"NA": 2}, "users": [{"025": [32.167671599999998, 119.4794266, "NA"]}, {"038": [40.069955, 116.3293766, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628529439.8208618, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677749944.5205517, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:28:15"	{"transports": {"NA": 2}, "users": [{"038": [40.069984900000001, 116.3274116, "NA"]}, {"025": [32.171860000000002, 119.47620499999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628534431.8230619, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677754936.5227518, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:28:30"	{"transports": {"NA": 2}, "users": [{"025": [32.17597, 119.4729499, "NA"]}, {"038": [40.070113300000003, 116.32406159999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628539424.6615038, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677759929.3611937, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:28:45"	{"transports": {"NA": 2}, "users": [{"038": [40.071891600000001, 116.3235566, "NA"]}, {"025": [32.180036600000001, 119.4697166, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628544418.2535906, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677764922.9532804, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:29:00"	{"transports": {"NA": 2}, "users": [{"025": [32.183478299999997, 119.46611660000001, "NA"]}, {"038": [40.0731866, 116.32330330000001, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628737360.0412607, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677497941.1803942, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:29:15"	{"transports": {"NA": 2}, "users": [{"038": [40.0747699, 116.32306989999999, "NA"]}, {"025": [32.186053299999998, 119.4622883, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628742354.9299173, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677502936.0690508, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:29:30"	{"transports": {"NA": 2}, "users": [{"025": [32.188411600000002, 119.4588483, "NA"]}, {"038": [40.076534899999999, 116.32276830000001, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628747350.4331503, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677507931.5722837, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:29:45"	{"transports": {"NA": 2}, "users": [{"038": [40.077886599999999, 116.3221983, "NA"]}, {"025": [32.190649899999997, 119.4555599, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628752346.4938917, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677512927.6330252, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:30:00"	{"transports": {"NA": 2}, "users": [{"025": [32.192823300000001, 119.4522999, "NA"]}, {"038": [40.078026600000001, 116.3229383, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623581395.8782225, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5671001520.0692148, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:30:15"	{"transports": {"NA": 2}, "users": [{"025": [32.194981599999998, 119.44905660000001, "NA"]}, {"038": [40.0785883, 116.3245766, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623586392.9521542, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5671006517.1431465, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:30:30"	{"transports": {"NA": 2}, "users": [{"025": [32.1971433, 119.44584999999999, "NA"]}, {"038": [40.078639899999999, 116.32495160000001, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623591390.44911, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5671011514.6401024, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:30:45"	{"transports": {"NA": 2}, "users": [{"025": [32.199271600000003, 119.44262329999999, "NA"]}, {"038": [40.078639899999999, 116.32495160000001, "NA"]}], "dists": {"taxi": 34449655.39787472, "bike": 50164025.702512085, "all": 6623596388.3311825, "run": 97192.982603142751, "car": 187697404.43362495, "NA": 5671016512.5221748, "walk": 41983153.228389852, "train": 392282454.74285144, "motorcycle": 52060.024369348619, "bus": 152428030.4421005, "airplane": 62466632.153962083, "boat": 1475381.3410107866, "subway": 29483885.359411184}}
# "2009-02-06 14:31:00"	{"transports": {"NA": 2}, "users": [{"025": [32.200641599999997, 119.43904329999999, "NA"]}, {"038": [40.078641599999997, 116.3249483, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628549416.5080309, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677769921.2077208, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:31:15"	{"transports": {"NA": 2}, "users": [{"038": [40.078794899999998, 116.3250433, "NA"]}, {"025": [32.200994899999998, 119.4353483, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628554415.1363754, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677774919.8360653, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:31:30"	{"transports": {"NA": 2}, "users": [{"038": [40.078933300000003, 116.32495489999999, "NA"]}, {"025": [32.200634899999997, 119.43226989999999, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628559414.0753326, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677779918.7750225, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:31:45"	{"transports": {"NA": 2}, "users": [{"038": [40.079139900000001, 116.325125, "NA"]}, {"025": [32.200278300000001, 119.4297416, "NA"]}], "dists": {"taxi": 34457837.415625125, "bike": 50194578.97080332, "all": 6628564413.2850122, "run": 96822.942598367124, "car": 187661693.43766725, "NA": 5677784917.9847021, "walk": 42050887.994130239, "train": 390331881.44590056, "motorcycle": 52343.449584375317, "bus": 152517833.46084958, "airplane": 62502209.044203579, "boat": 1474686.3040510698, "subway": 29438720.834572729}}
# "2009-02-06 14:32:00"	{"transports": {"NA": 2}, "users": [{"025": [32.199939999999998, 119.4279683, "NA"]}, {"038": [40.079196600000003, 116.32517660000001, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628757345.8836794, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677517927.0228128, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:32:15"	{"transports": {"NA": 2}, "users": [{"038": [40.079344900000002, 116.3254566, "NA"]}, {"025": [32.199678300000002, 119.4266116, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628762345.4424963, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677522926.5816298, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:32:30"	{"transports": {"NA": 2}, "users": [{"038": [40.079398300000001, 116.32568329999999, "NA"]}, {"025": [32.199530000000003, 119.4258316, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628767345.1019249, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677527926.2410583, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# "2009-02-06 14:32:45"	{"transports": {"NA": 2}, "users": [{"025": [32.199511600000001, 119.42574329999999, "NA"]}, {"038": [40.079266599999997, 116.3257849, "NA"]}], "dists": {"taxi": 34473489.679498672, "bike": 50158571.124229282, "all": 6628772344.7882519, "run": 96756.113650342886, "car": 187270713.33558577, "NA": 5677532925.9273853, "walk": 42005737.925947756, "train": 391698544.22684771, "motorcycle": 52451.209305263634, "bus": 152720573.31034198, "airplane": 61922757.514691383, "boat": 1460635.2400128066, "subway": 29379189.180327512}}
# ...
# "2009-02-07 15:12:00"	{"transports": {"NA": 2}, "users": [{"038": [39.9074533, 116.4534616, "NA"]}, {"028": [39.967730000000003, 116.101544, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635611202.3190088, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680751155.3450241, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:12:15"	{"transports": {"NA": 2}, "users": [{"028": [39.967730000000003, 116.101544, "NA"]}, {"038": [39.907823299999997, 116.4524383, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635611948.6273117, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680751901.653327, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:12:30"	{"transports": {"NA": 2}, "users": [{"038": [39.9080899, 116.45072, "NA"]}, {"028": [39.967730000000003, 116.101544, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635612695.0878086, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680752648.1138239, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:12:45"	{"transports": {"NA": 2}, "users": [{"028": [39.967731000000001, 116.101545, "NA"]}, {"038": [39.908140000000003, 116.4488116, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635613441.7117805, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680753394.7377958, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:13:00"	{"transports": {"NA": 2}, "users": [{"038": [39.907853299999999, 116.44582490000001, "NA"]}, {"028": [39.967731000000001, 116.101545, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640847773.6534643, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687627254.9188137, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:13:15"	{"transports": {"NA": 2}, "users": [{"028": [39.967731000000001, 116.101545, "NA"]}, {"038": [39.907620000000001, 116.44309, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640848520.7834015, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687628002.0487509, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:13:30"	{"transports": {"NA": 2}, "users": [{"028": [39.967730000000003, 116.101545, "NA"]}, {"038": [39.908313300000003, 116.44168000000001, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640849268.0969019, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687628749.3622513, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:13:45"	{"transports": {"NA": 1}, "users": [{"028": [39.967730000000003, 116.101545, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640849935.8141518, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687629417.0795012, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:14:00"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.101546, "NA"]}, {"038": [39.906289999999998, 116.4388783, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641454102.7197704, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687561364.4456663, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:14:15"	{"transports": {"NA": 2}, "users": [{"038": [39.906011599999999, 116.4351549, "NA"]}, {"028": [39.967731999999998, 116.101547, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641454850.6927891, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687562112.418685, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:14:30"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10154799999999, "NA"]}, {"038": [39.906019999999998, 116.43334830000001, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641455598.8359928, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687562860.5618887, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:14:45"	{"transports": {"NA": 2}, "users": [{"038": [39.906238299999998, 116.4323799, "NA"]}, {"028": [39.967731000000001, 116.10154900000001, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641456347.0751591, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687563608.801055, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:15:00"	{"transports": {"NA": 2}, "users": [{"038": [39.906186599999998, 116.43070659999999, "NA"]}, {"028": [39.967731999999998, 116.10154900000001, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635614190.0941114, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680754143.1201267, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:15:15"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10154900000001, "NA"]}, {"038": [39.9060816, 116.4298883, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635614938.5626984, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680754891.5887136, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:15:30"	{"transports": {"NA": 2}, "users": [{"038": [39.906214900000002, 116.4295233, "NA"]}, {"028": [39.967731999999998, 116.10154900000001, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635615687.0833559, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680755640.1093712, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:15:45"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10154900000001, "NA"]}, {"038": [39.906436599999999, 116.42923, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635616435.6430769, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680756388.6690922, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:16:00"	{"transports": {"NA": 2}, "users": [{"028": [39.967733000000003, 116.10154900000001, "NA"]}, {"038": [39.906456599999999, 116.4287416, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640850684.4157143, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687630165.6810637, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:16:15"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10155, "NA"]}, {"038": [39.906436599999999, 116.4269666, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640851433.1690893, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687630914.4344387, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:16:30"	{"transports": {"NA": 2}, "users": [{"038": [39.906498300000003, 116.4252583, "NA"]}, {"028": [39.967731999999998, 116.10154900000001, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640852182.0700798, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687631663.3354292, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:16:45"	{"transports": {"NA": 2}, "users": [{"038": [39.906473300000002, 116.423135, "NA"]}, {"028": [39.967731999999998, 116.10154799999999, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640852931.153039, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687632412.4183884, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}
# "2009-02-07 15:17:00"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10154900000001, "NA"]}, {"038": [39.906546599999999, 116.42125, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641457096.3194866, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687564358.0453825, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:17:15"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10154900000001, "NA"]}, {"038": [39.906608300000002, 116.4200116, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641457845.6776333, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687565107.4035292, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:17:30"	{"transports": {"NA": 2}, "users": [{"028": [39.967731999999998, 116.10154900000001, "NA"]}, {"038": [39.907863300000002, 116.42005159999999, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641458595.1761379, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687565856.9020338, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:17:45"	{"transports": {"NA": 2}, "users": [{"038": [39.907339999999998, 116.42055499999999, "NA"]}, {"028": [39.967731999999998, 116.10154900000001, "NA"]}], "dists": {"taxi": 34556946.778018579, "bike": 50228091.440188304, "all": 6641459344.7665977, "run": 96756.113650342886, "car": 187333120.06002176, "NA": 5687566606.4924936, "walk": 42047530.666271776, "train": 393911139.2485581, "motorcycle": 52683.621173818261, "bus": 152859016.69214287, "airplane": 61923567.463598698, "boat": 1460635.2400128066, "subway": 29423250.950042352}}
# "2009-02-07 15:18:00"	{"transports": {"NA": 2}, "users": [{"038": [39.905401599999998, 116.4206449, "NA"]}, {"028": [39.967731000000001, 116.10154799999999, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635617185.4496632, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680757138.4756784, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:18:15"	{"transports": {"NA": 2}, "users": [{"038": [39.903729900000002, 116.4207033, "NA"]}, {"028": [39.967730000000003, 116.10154900000001, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635617935.4425049, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680757888.4685202, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:18:30"	{"transports": {"NA": 2}, "users": [{"028": [39.967728000000001, 116.10155, "NA"]}, {"038": [39.903080000000003, 116.42048, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635618685.5530748, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680758638.5790901, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:18:45"	{"transports": {"NA": 2}, "users": [{"028": [39.967728000000001, 116.101551, "NA"]}, {"038": [39.902979999999999, 116.41874660000001, "NA"]}], "dists": {"taxi": 34521817.25211902, "bike": 50227108.952178605, "all": 6635619435.8124943, "run": 97192.982603142751, "car": 187754197.63298148, "NA": 5680759388.8385096, "walk": 42020632.314583801, "train": 394172095.20443946, "motorcycle": 52270.916620444485, "bus": 152550394.72911879, "airplane": 62467321.321014799, "boat": 1475381.3410107866, "subway": 29521634.32701385}}
# "2009-02-07 15:19:00"	{"transports": {"NA": 2}, "users": [{"028": [39.967726999999996, 116.101552, "NA"]}, {"038": [39.903039999999997, 116.41786329999999, "NA"]}], "dists": {"taxi": 34535004.851393104, "bike": 50261524.460245341, "all": 6640853681.4886284, "run": 96822.942598367124, "car": 187722176.38115871, "NA": 5687633162.7539778, "walk": 42090754.095044062, "train": 392356659.50666034, "motorcycle": 52567.25360594644, "bus": 152648226.31545693, "airplane": 62502947.944961131, "boat": 1474686.3040510698, "subway": 29479148.679162394}}

# %%
# !tail ../../Geolife_Trajectories_1.3/local/aggregate3/*
# Out:
# "2012-07-27 08:29:15"	{"transports": {"NA": 1}, "users": [{"163": [39.984516663000001, 116.302059985, "NA"]}], "dists": {"taxi": 224437473.5948672, "bike": 178473996.42709351, "all": 16358282639.816271, "run": 315225.50981017883, "car": 1207154157.5819829, "NA": 12181561488.944613, "walk": 169046654.79581863, "train": 847398608.83221841, "motorcycle": 55498.859239258752, "bus": 388751424.79077607, "airplane": 952441013.49000311, "boat": 12291782.708254633, "subway": 196355314.28493583}}
# "2012-07-27 08:29:30"	{"transports": {"NA": 1}, "users": [{"163": [39.983167424000001, 116.302093149, "NA"]}], "dists": {"taxi": 224438240.89011696, "bike": 178474162.90533072, "all": 16358303762.330982, "run": 315225.50981017883, "car": 1207154504.7932734, "NA": 12181579141.232082, "walk": 169046901.61761644, "train": 847400401.60531616, "motorcycle": 55498.859239258752, "bus": 388751530.29471862, "airplane": 952441030.35604715, "boat": 12291782.708254633, "subway": 196355341.56251875}}
# "2012-07-27 08:29:45"	{"transports": {"NA": 1}, "users": [{"163": [39.98172641, 116.302066962, "NA"]}], "dists": {"taxi": 224439008.18536672, "bike": 178474329.38356793, "all": 16358324885.005959, "run": 315225.50981017883, "car": 1207154852.004564, "NA": 12181596793.679815, "walk": 169047148.43941426, "train": 847402194.37841392, "motorcycle": 55498.859239258752, "bus": 388751635.79866117, "airplane": 952441047.2220912, "boat": 12291782.708254633, "subway": 196355368.84010166}}
# "2012-07-27 08:30:00"	{"transports": {"NA": 1}, "users": [{"163": [39.981367999, 116.302112986, "NA"]}], "dists": {"taxi": 224170520.57039359, "bike": 178032711.89361256, "all": 16334502965.32497, "run": 313694.93938739772, "car": 1201626146.0276277, "NA": 12173351204.821161, "walk": 168929771.67455047, "train": 844570202.35423934, "motorcycle": 55786.588377777203, "bus": 388460452.35133058, "airplane": 947276684.95818281, "boat": 12230310.656464417, "subway": 195485478.49267367}}
# "2012-07-27 08:30:15"	{"transports": {"NA": 1}, "users": [{"163": [39.981102112000002, 116.302838884, "NA"]}], "dists": {"taxi": 224171287.86564335, "bike": 178032878.37184978, "all": 16334524088.120092, "run": 313694.93938739772, "car": 1201626493.2389183, "NA": 12173368857.389042, "walk": 168930018.49634829, "train": 844571995.1273371, "motorcycle": 55786.588377777203, "bus": 388460557.85527313, "airplane": 947276701.82422686, "boat": 12230310.656464417, "subway": 195485505.77025658}}
# "2012-07-27 08:30:30"	{"transports": {"NA": 1}, "users": [{"163": [39.980758541999997, 116.30336708900001, "NA"]}], "dists": {"taxi": 224172055.16089311, "bike": 178033044.85008699, "all": 16334545210.988155, "run": 313694.93938739772, "car": 1201626840.4502089, "NA": 12173386510.029863, "walk": 168930265.31814611, "train": 844573787.90043485, "motorcycle": 55786.588377777203, "bus": 388460663.35921568, "airplane": 947276718.6902709, "boat": 12230310.656464417, "subway": 195485533.04783949}}
# "2012-07-27 08:30:45"	{"transports": {"NA": 1}, "users": [{"163": [39.979523974000003, 116.303445903, "NA"]}], "dists": {"taxi": 224172822.45614287, "bike": 178033211.3283242, "all": 16334566333.993795, "run": 313694.93938739772, "car": 1201627187.6614995, "NA": 12173404162.80826, "walk": 168930512.13994393, "train": 844575580.67353261, "motorcycle": 55786.588377777203, "bus": 388460768.86315823, "airplane": 947276735.55631495, "boat": 12230310.656464417, "subway": 195485560.32542241}}
# "2012-07-27 08:31:00"	{"transports": {"NA": 1}, "users": [{"163": [39.979480699, 116.303498873, "NA"]}], "dists": {"taxi": 224239575.34476307, "bike": 178047438.77518097, "all": 16341471063.09539, "run": 313804.78876111831, "car": 1202372575.2609076, "NA": 12176731519.373663, "walk": 168898912.44655693, "train": 846388612.74491584, "motorcycle": 55958.906951041805, "bus": 388715086.51730216, "airplane": 947877513.85958457, "boat": 12228480.9495994, "subway": 195601584.12877896}}
# "2012-07-27 08:31:15"	{"transports": {"NA": 1}, "users": [{"163": [39.979190224, 116.303586725, "NA"]}], "dists": {"taxi": 224240342.64001283, "bike": 178047605.25341818, "all": 16341492186.142586, "run": 313804.78876111831, "car": 1202372922.4721982, "NA": 12176749172.193615, "walk": 168899159.26835474, "train": 846390405.5180136, "motorcycle": 55958.906951041805, "bus": 388715192.0212447, "airplane": 947877530.72562861, "boat": 12228480.9495994, "subway": 195601611.40636188}}
# "2012-07-27 08:31:30"	{"transports": {"NA": 1}, "users": [{"163": [39.979080862000004, 116.30357232, "NA"]}], "dists": {"taxi": 224241109.93526259, "bike": 178047771.73165539, "all": 16341513309.202003, "run": 313804.78876111831, "car": 1202373269.6834888, "NA": 12176766825.025789, "walk": 168899406.09015256, "train": 846392198.29111135, "motorcycle": 55958.906951041805, "bus": 388715297.52518725, "airplane": 947877547.59167266, "boat": 12228480.9495994, "subway": 195601638.68394479}}

# %% [markdown]
# #Summary Statistics

# %%
# !tail n10000 ../../Geolife_Trajectories_1.3/final_output/*

# %%
# !aws s3 cp --recursive s3://w209-d3/aggregate3/  ../../Geolife_Trajectories_1.3/aggregate3/
# Out:
# download: s3://w209-d3/aggregate3/data_csv/_SUCCESS to ../../Geolife_Trajectories_1.3/aggregate3/data_csv/_SUCCESS
# download: s3://w209-d3/aggregate3/data_csv/part-00000 to ../../Geolife_Trajectories_1.3/aggregate3/data_csv/part-00000

# %%
# !mv ../../Geolife_Trajectories_1.3/aggregate3/ ../../Geolife_Trajectories_1.3/local/aggregate3/
